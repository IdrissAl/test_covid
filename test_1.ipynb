# %%
import pandas, sys
import pandas as pd # librairaire panda

# %%
# code pour lire le fichier csv sur le Drive Afganistan
url='https://drive.google.com/file/d/1EKSl-ouVpjjaRfCFTYR0j8RgyrFL6ksd/view?usp=sharing'
url2='https://drive.google.com/uc?id=' + url.split('/')[-2] 
df = pd.read_csv(url2)

# %%
# Albanie
url_1='https://drive.google.com/file/d/1eLCj4GTNwu3w7n6Cjo0QNBmqFGlklMum/view?usp=sharing'
url22='https://drive.google.com/uc?id=' + url_1.split('/')[-2]
df2 = pd.read_csv(url22)

# %%
df
# Out:
#           Entity Code         Day  total_tests  142601-annotations  \
# 0    Afghanistan  AFG  2020-03-22          NaN                 NaN
# 1    Afghanistan  AFG  2020-03-23          NaN                 NaN
# 2    Afghanistan  AFG  2020-03-24          NaN                 NaN
# 3    Afghanistan  AFG  2020-03-25          NaN                 NaN
# 4    Afghanistan  AFG  2020-03-26          NaN                 NaN
# ..           ...  ...         ...          ...                 ...
# 464  Afghanistan  AFG  2020-03-17          NaN                 NaN
# 465  Afghanistan  AFG  2020-03-18          NaN                 NaN
# 466  Afghanistan  AFG  2020-03-19          NaN                 NaN
# 467  Afghanistan  AFG  2020-03-20          NaN                 NaN
# 468  Afghanistan  AFG  2020-03-21          NaN                 NaN
#
#      Total confirmed deaths due to COVID-19  Total confirmed cases of COVID-19
# 0                                       1.0                              10000
# ...

# %%
df2
# Out:
#       Entity Code         Day  total_tests 142601-annotations  \
# 0    Albania  ALB  2020-02-25          8.0    tests performed
# 1    Albania  ALB  2020-02-26         13.0    tests performed
# 2    Albania  ALB  2020-02-27         17.0    tests performed
# 3    Albania  ALB  2020-02-28         18.0    tests performed
# 4    Albania  ALB  2020-02-29         26.0    tests performed
# ..       ...  ...         ...          ...                ...
# 463  Albania  ALB  2021-06-02          NaN                NaN
# 464  Albania  ALB  2021-06-03          NaN                NaN
# 465  Albania  ALB  2021-06-04          NaN                NaN
# 466  Albania  ALB  2021-06-05          NaN                NaN
# 467  Albania  ALB  2021-06-06          NaN                NaN
#
#      Total confirmed deaths due to COVID-19  Total confirmed cases of COVID-19
# 0                                       NaN                                NaN
# ...

# %%
d1 = pd.DataFrame(df)
d2 = pd.DataFrame(df2)
frames = [d1, d2]

result=pd.concat(frames)

# %%
result
# Out:
#           Entity Code         Day  total_tests 142601-annotations  \
# 0    Afghanistan  AFG  2020-03-22          NaN                NaN
# 1    Afghanistan  AFG  2020-03-23          NaN                NaN
# 2    Afghanistan  AFG  2020-03-24          NaN                NaN
# 3    Afghanistan  AFG  2020-03-25          NaN                NaN
# 4    Afghanistan  AFG  2020-03-26          NaN                NaN
# ..           ...  ...         ...          ...                ...
# 463      Albania  ALB  2021-06-02          NaN                NaN
# 464      Albania  ALB  2021-06-03          NaN                NaN
# 465      Albania  ALB  2021-06-04          NaN                NaN
# 466      Albania  ALB  2021-06-05          NaN                NaN
# 467      Albania  ALB  2021-06-06          NaN                NaN
#
#      Total confirmed deaths due to COVID-19  Total confirmed cases of COVID-19
# 0                                       1.0                            10000.0
# ...
